# %%
import pandas as pd
df=pd.read_csv('tox.csv')
s1=df[['NR-AR','mol_id','smiles']]
s2=df[['NR-AR-LBD','mol_id','smiles']]
s3=df[['NR-AhR','mol_id','smiles']]
s4=df[['NR-Aromatase','mol_id','smiles']]
s5=df[['NR-ER','mol_id','smiles']]
s6=df[['NR-ER-LBD','mol_id','smiles']]
s7=df[['NR-PPAR-gamma','mol_id','smiles']]
s8=df[['SR-ARE','mol_id','smiles']]
s9=df[['SR-ATAD5','mol_id','smiles']]
s10=df[['SR-HSE','mol_id','smiles']]
s11=df[['SR-MMP','mol_id','smiles']]
s12=df[['SR-p53','mol_id','smiles']]
writer = pd.ExcelWriter('tox2.xlsx')
m1=s1.dropna(axis=0,how='any')
m2=s2.dropna(axis=0,how='any')
m3=s3.dropna(axis=0,how='any')
m4=s4.dropna(axis=0,how='any')
m5=s5.dropna(axis=0,how='any')
m6=s6.dropna(axis=0,how='any')
m7=s7.dropna(axis=0,how='any')
m8=s8.dropna(axis=0,how='any')
m9=s9.dropna(axis=0,how='any')
m10=s10.dropna(axis=0,how='any')
m11=s11.dropna(axis=0,how='any')
m12=s12.dropna(axis=0,how='any')
m1.to_excel(excel_writer=writer,sheet_name='1')
m2.to_excel(excel_writer=writer,sheet_name='2')
m3.to_excel(excel_writer=writer,sheet_name='3')
m4.to_excel(excel_writer=writer,sheet_name='4')
m5.to_excel(excel_writer=writer,sheet_name='5')
m6.to_excel(excel_writer=writer,sheet_name='6')
m7.to_excel(excel_writer=writer,sheet_name='7')
m8.to_excel(excel_writer=writer,sheet_name='8')
m9.to_excel(excel_writer=writer,sheet_name='9')
m10.to_excel(excel_writer=writer,sheet_name='10')
m11.to_excel(excel_writer=writer,sheet_name='11')
m12.to_excel(excel_writer=writer,sheet_name='12')
def xlsx_to_csv_pd():
    data_xls = pd.read_excel('tox2.xlsx', index_col=0)
    data_xls.to_csv('tox2.csv', encoding='utf-8')
if __name__ == '__main__':
    xlsx_to_csv_pd()
writer.save()
writer.close()

# %%
由于导入csv文件不存在sheet，所以保存时候没法保存为csv，所以就直接保存为csv文件

# %%
import pandas as pd
df=pd.read_csv('tox.csv')
s1=df[['NR-AR','mol_id','smiles']]
s2=df[['NR-AR-LBD','mol_id','smiles']]
s3=df[['NR-AhR','mol_id','smiles']]
s4=df[['NR-Aromatase','mol_id','smiles']]
s5=df[['NR-ER','mol_id','smiles']]
s6=df[['NR-ER-LBD','mol_id','smiles']]
s7=df[['NR-PPAR-gamma','mol_id','smiles']]
s8=df[['SR-ARE','mol_id','smiles']]
s9=df[['SR-ATAD5','mol_id','smiles']]
s10=df[['SR-HSE','mol_id','smiles']]
s11=df[['SR-MMP','mol_id','smiles']]
s12=df[['SR-p53','mol_id','smiles']]
m1=s1.dropna(axis=0,how='any')
m2=s2.dropna(axis=0,how='any')
m3=s3.dropna(axis=0,how='any')
m4=s4.dropna(axis=0,how='any')
m5=s5.dropna(axis=0,how='any')
m6=s6.dropna(axis=0,how='any')
m7=s7.dropna(axis=0,how='any')
m8=s8.dropna(axis=0,how='any')
m9=s9.dropna(axis=0,how='any')
m10=s10.dropna(axis=0,how='any')
m11=s11.dropna(axis=0,how='any')
m12=s12.dropna(axis=0,how='any')
file=m1.to_csv('1.csv',encoding='utf-8')
file=m2.to_csv('2.csv',encoding='utf-8')
file=m3.to_csv('3.csv',encoding='utf-8')
file=m4.to_csv('4.csv',encoding='utf-8')
file=m5.to_csv('5.csv',encoding='utf-8')
file=m6.to_csv('6.csv',encoding='utf-8')
file=m7.to_csv('7.csv',encoding='utf-8')
file=m8.to_csv('8.csv',encoding='utf-8')
file=m9.to_csv('9.csv',encoding='utf-8')
file=m10.to_csv('10.csv',encoding='utf-8')
file=m11.to_csv('11.csv',encoding='utf-8')
file=m12.to_csv('12.csv',encoding='utf-8')
